# %%
n=4
arr=[[' ']*(n+1) for i in range(n)]

# %%
arr
# Out:
# [[' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ']]

# %%
layers=(n+1)//2

# %%
layers
# Out:
# 2

# %%
layer=0
num=1
for i in range(layer,n-layer):
    arr[layer][i]=str(num)
    num+=1

for i in range(1+layer,n-layer):
    arr[layer+i][n-1]=str(num)
    num+=1


for i in range(n-layer-2,layer-1,-1):
    arr[n-1][i+layer]=str(num)
    num+=1

for i in range(n-layer-2,layer,-1):
    arr[i][layer]=str(num)
    num+=1

# %%
arr
# Out:
# [['1', '2', '3', '4'],
#  ['12', ' ', ' ', '5'],
#  ['11', ' ', ' ', '6'],
#  ['10', '9', '8', '7']]

# %%
n=5
def spiral(n):
    layers=(n+1)//2
    arr=[[' ']*n for i in range(n)]
    num=1
    for layer in range(layers):
        for i in range(layer,n-layer):
            arr[layer][i]=str(num)
            num+=1
        
        for i in range(1+layer,n-layer):
            arr[i][n-layer-1]=str(num)
            num+=1
        
        
        for i in range(n-layer-2,layer-1,-1):
            arr[n-layer-1][i]=str(num)
            num+=1
        
        for i in range(n-layer-2,layer,-1):
            arr[i][layer]=str(num)
            num+=1
    
    return arr

# %%
spiral(4)
# Out:
# [['1', '2', '3', '4'],
#  ['12', '13', '14', '5'],
#  ['11', '16', '15', '6'],
#  ['10', '9', '8', '7']]

# %%
arr
# Out:
# [['1', '2', '3', '4', '5'],
#  ['16', '17', '18', '19', '6'],
#  ['15', '24', '25', '20', '7'],
#  ['14', '23', '22', '21', '8'],
#  ['13', '12', '11', '10', '9']]

# %%
range(1+layer,n-layer)

# %%
i=2
arr[layer+i]
# Out:
# ['10', '9', '15', '7']

# %%
arr
# Out:
# [['1', '2', '3', '4'],
#  ['12', '13', '14', '5'],
#  ['11', '16', ' ', '6'],
#  ['10', '9', '15', '7']]

# %%
range(1+layer,n-layer)
# Out:
# range(2, 3)

# %%
layer=1

# %%
arr[layer+i][n-layer-1]
# Out:
# ' '

# %%
layer+i
# Out:
# 2

# %%
n-layer-1
# Out:
# 2

# %%
arr
# Out:
# [['1', '2', '3', '4'],
#  ['12', '13', '14', '5'],
#  ['11', ' ', ' ', '6'],
#  ['10', '9', '16', '7']]

# %%
arr[1+1][3-1-1]
# Out:
# ' '

# %%
range(1,3-1)
# Out:
# range(1, 2)

# %%
arr[1+2][n-1]
# Out:
# '15'

# %%
arr[2-1][n-1]
# Out:
# '5'

# %%
arr[2+1]
# Out:
# ['10', '9', '16', '7']

# %%
arr[2][2]
# Out:
# ' '

# %%
arr[layer+i][n-layer-1]
# Out:
# ' '
